# %%
import numpy as np

A = np.array([1,2,3,4,5])
B = np.array([6,7,8,9,10])

print(np.dot(A,B))
print(A@B)
# Out:
# 130
# 130

# %%
# Define 3 vectors
A = np.array([1,2,3])
B = np.array([4,5,6])
C = np.array([7,8,9])

# Calculate dot product using numpy.dot() function
dot_product_AB = np.dot(A,B)
dot_product_BA = np.dot(B,A)
print(dot_product_AB)
print(dot_product_BA)

# Check commulative property: A . B = B . A
if dot_product_AB == dot_product_BA:
    print("This dot product is commulative.")
else:
    print("This dot product is not commulative.")
# Out:
# 32
# 32
# This dot product is commulative.

# %%
# Check distributive property: A . (B + C) = A . B + A . C
dot_product_A_BC = np.dot(A,B+C)
dot_product_AB_plus_AC = np.dot(A,B) + np.dot(A,C)
print(dot_product_A_BC)
print(dot_product_AB_plus_AC)

if dot_product_A_BC == dot_product_AB_plus_AC:
    print("The dot product is distributive.")
else:
    print("The dot product is not distributive.")
# Out:
# 82
# 82
# The dot product is distributive.

# %%
# Define 3 vectors
A = np.array([1,2,3])
B = np.array([-4,-5,-6])
C = np.array([5,5,5])

# Calculate the cosine similarity
cosine_similarity = np.dot(A,B) / (np.linalg.norm(A) * np.linalg.norm(B))
print(cosine_similarity)

# Claculate the cosine similarity
cosine_similarity1 = np.dot(A,C) / (np.linalg.norm(A) * np.linalg.norm(B))
print(cosine_similarity1)
# Out:
# -0.9746318461970762
# 0.913717355809759
